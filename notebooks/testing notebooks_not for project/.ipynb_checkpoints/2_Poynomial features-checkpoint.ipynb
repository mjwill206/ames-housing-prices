# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import RidgeCV, LassoCV

import warnings

warnings.filterwarnings('ignore')

train = pd.read_csv('../datasets/train.csv')

# %%
train.drop(columns = ['Pool QC', 'Pool Area'], inplace = True)

# %%
train.drop(columns = ['Alley'], inplace = True)

# %%
train.drop(columns = ['Misc Feature', 'Misc Val'], inplace = True)

# %%
train.drop(columns = ['Fence'], inplace = True)

# %%
train['Mas Vnr Type'].fillna('None', inplace = True)
train['Mas Vnr Area'].fillna(0, inplace = True)

# %%
train['Bsmt Qual'].fillna('NA', inplace = True)
train['Bsmt Cond'].fillna('NA', inplace = True)
train['Bsmt Exposure'].fillna('NA', inplace = True)
train['BsmtFin Type 1'].fillna('NA', inplace = True)
train['BsmtFin Type 2'].fillna('NA', inplace = True)
train['BsmtFin SF 1'].fillna(0, inplace = True)
train['BsmtFin SF 2'].fillna(0, inplace = True)
train['Bsmt Unf SF'].fillna(0, inplace = True)
train['Total Bsmt SF'].fillna(0, inplace = True)
train['Bsmt Full Bath'].fillna(0, inplace = True)
train['Bsmt Half Bath'].fillna(0, inplace = True)

# %%
train['Garage Type'].fillna('NA', inplace = True)
train['Garage Finish'].fillna('NA', inplace = True)
train['Garage Qual'].fillna('NA', inplace = True)
train['Garage Cond'].fillna('NA', inplace = True)
train['Garage Cars'].fillna(0, inplace = True)
train['Garage Area'].fillna(0, inplace = True)
train['Bsmt Unf SF'].fillna(0, inplace = True)
train.drop(columns = 'Garage Yr Blt', inplace = True)

# %%
train['Fireplace Qu'].fillna('NA', inplace = True)

# %%
train['Lot Frontage'].fillna(0, inplace = True)

# %%
train.drop([960, 1885], inplace = True)

# %%
train.drop([471, 694, 1854], inplace = True)

# %%
train['porch sf'] = train['Wood Deck SF'] + train['Open Porch SF'] + \
                    train['Enclosed Porch'] + train['3Ssn Porch'] + \
                    train['Screen Porch']

# %%
train['age at sale'] = train['Yr Sold'] - train['Year Built']

# %%
train['age remod'] = train['Yr Sold'] - train['Year Remod/Add']

# %%
train['total baths'] = train['Full Bath'] + train['Half Bath'] + train['Bsmt Full Bath'] + train['Bsmt Half Bath']

# %%
train['garage area_cars'] = train['Garage Area'] * train['Garage Cars']

# %%
train['finish bsmt sf'] = train['BsmtFin SF 1'] + train['BsmtFin SF 2']

# %%
poly = PolynomialFeatures(include_bias = False)

# %%
features = ['Overall Qual', 'Gr Liv Area', 'garage area_cars', 'age at sale',
          'age remod', 'porch sf', 'finish bsmt sf', 'total baths',
          'Mas Vnr Area', 'Fireplaces','Bedroom AbvGr', 'Kitchen AbvGr', 
          'Lot Area', 'Lot Frontage', 'Overall Cond']
X = train[features]

# %%
X_poly = poly.fit_transform(X)

# %%
poly.get_feature_names(features)
# Out:
# ['Overall Qual',
#  'Gr Liv Area',
#  'garage area_cars',
#  'age at sale',
#  'age remod',
#  'porch sf',
#  'finish bsmt sf',
#  'total baths',
#  'Mas Vnr Area',
#  'Fireplaces',
#  'Bedroom AbvGr',
#  'Kitchen AbvGr',
#  'Lot Area',
#  'Lot Frontage',
#  'Overall Cond',
#  'Overall Qual^2',
#  'Overall Qual Gr Liv Area',
#  'Overall Qual garage area_cars',
#  'Overall Qual age at sale',
#  'Overall Qual age remod',
#  'Overall Qual porch sf',
#  'Overall Qual finish bsmt sf',
#  'Overall Qual total baths',
#  'Overall Qual Mas Vnr Area',
#  'Overall Qual Fireplaces',
#  'Overall Qual Bedroom AbvGr',
#  'Overall Qual Kitchen AbvGr',
#  'Overall Qual Lot Area',
#  'Overall Qual Lot Frontage',
#  'Overall Qual Overall Cond',
#  'Gr Liv Area^2',
#  'Gr Liv Area garage area_cars',
#  'Gr Liv Area age at sale',
#  'Gr Liv Area age remod',
#  'Gr Liv Area porch sf',
#  'Gr Liv Area finish bsmt sf',
#  'Gr Liv Area total baths',
#  'Gr Liv Area Mas Vnr Area',
#  'Gr Liv Area Fireplaces',
#  'Gr Liv Area Bedroom AbvGr',
#  'Gr Liv Area Kitchen AbvGr',
#  'Gr Liv Area Lot Area',
#  'Gr Liv Area Lot Frontage',
#  'Gr Liv Area Overall Cond',
#  'garage area_cars^2',
#  'garage area_cars age at sale',
#  'garage area_cars age remod',
#  'garage area_cars porch sf',
#  'garage area_cars finish bsmt sf',
#  'garage area_cars total baths',
#  'garage area_cars Mas Vnr Area',
#  'garage area_cars Fireplaces',
#  'garage area_cars Bedroom AbvGr',
#  'garage area_cars Kitchen AbvGr',
#  'garage area_cars Lot Area',
#  'garage area_cars Lot Frontage',
#  'garage area_cars Overall Cond',
#  'age at sale^2',
#  'age at sale age remod',
#  'age at sale porch sf',
#  'age at sale finish bsmt sf',
#  'age at sale total baths',
#  'age at sale Mas Vnr Area',
#  'age at sale Fireplaces',
#  'age at sale Bedroom AbvGr',
#  'age at sale Kitchen AbvGr',
#  'age at sale Lot Area',
#  'age at sale Lot Frontage',
#  'age at sale Overall Cond',
#  'age remod^2',
#  'age remod porch sf',
#  'age remod finish bsmt sf',
#  'age remod total baths',
#  'age remod Mas Vnr Area',
#  'age remod Fireplaces',
#  'age remod Bedroom AbvGr',
#  'age remod Kitchen AbvGr',
#  'age remod Lot Area',
#  'age remod Lot Frontage',
#  'age remod Overall Cond',
#  'porch sf^2',
#  'porch sf finish bsmt sf',
#  'porch sf total baths',
#  'porch sf Mas Vnr Area',
#  'porch sf Fireplaces',
#  'porch sf Bedroom AbvGr',
#  'porch sf Kitchen AbvGr',
#  'porch sf Lot Area',
#  'porch sf Lot Frontage',
#  'porch sf Overall Cond',
#  'finish bsmt sf^2',
#  'finish bsmt sf total baths',
#  'finish bsmt sf Mas Vnr Area',
#  'finish bsmt sf Fireplaces',
#  'finish bsmt sf Bedroom AbvGr',
#  'finish bsmt sf Kitchen AbvGr',
#  'finish bsmt sf Lot Area',
#  'finish bsmt sf Lot Frontage',
#  'finish bsmt sf Overall Cond',
#  'total baths^2',
#  'total baths Mas Vnr Area',
#  'total baths Fireplaces',
#  'total baths Bedroom AbvGr',
#  'total baths Kitchen AbvGr',
#  'total baths Lot Area',
#  'total baths Lot Frontage',
#  'total baths Overall Cond',
#  'Mas Vnr Area^2',
#  'Mas Vnr Area Fireplaces',
#  'Mas Vnr Area Bedroom AbvGr',
#  'Mas Vnr Area Kitchen AbvGr',
#  'Mas Vnr Area Lot Area',
#  'Mas Vnr Area Lot Frontage',
#  'Mas Vnr Area Overall Cond',
#  'Fireplaces^2',
#  'Fireplaces Bedroom AbvGr',
#  'Fireplaces Kitchen AbvGr',
#  'Fireplaces Lot Area',
#  'Fireplaces Lot Frontage',
#  'Fireplaces Overall Cond',
#  'Bedroom AbvGr^2',
#  'Bedroom AbvGr Kitchen AbvGr',
#  'Bedroom AbvGr Lot Area',
#  'Bedroom AbvGr Lot Frontage',
#  'Bedroom AbvGr Overall Cond',
#  'Kitchen AbvGr^2',
#  'Kitchen AbvGr Lot Area',
#  'Kitchen AbvGr Lot Frontage',
#  'Kitchen AbvGr Overall Cond',
#  'Lot Area^2',
#  'Lot Area Lot Frontage',
#  'Lot Area Overall Cond',
#  'Lot Frontage^2',
#  'Lot Frontage Overall Cond',
#  'Overall Cond^2']

# %%
pd.DataFrame(X_poly,
             columns = poly.get_feature_names(features))
# Out:
#       Overall Qual  Gr Liv Area  garage area_cars  age at sale  age remod  \
# 0              6.0       1479.0             950.0         34.0        5.0
# 1              7.0       2122.0            1118.0         13.0       12.0
# 2              5.0       1057.0             246.0         57.0        3.0
# 3              5.0       1444.0             800.0          4.0        3.0
# 4              6.0       1445.0             968.0        110.0       17.0
# ...            ...          ...               ...          ...        ...
# 2041           8.0       1728.0            1040.0          1.0        1.0
# 2042           4.0        861.0            1078.0         69.0       59.0
# 2043           6.0       1913.0             684.0         81.0       59.0
# 2044           4.0       1200.0             294.0         53.0       53.0
# 2045           7.0       1804.0             884.0         11.0       11.0
#
#       porch sf  finish bsmt sf  total baths  Mas Vnr Area  Fireplaces  ...  \
# 0         44.0           533.0          3.0         289.0         0.0  ...
# 1         74.0           637.0          4.0         132.0         1.0  ...
# 2         52.0           731.0          2.0           0.0         0.0  ...
# 3        100.0             0.0          3.0           0.0         0.0  ...
# 4         59.0             0.0          2.0           0.0         0.0  ...
# ...        ...             ...          ...           ...         ...  ...
# 2041     276.0          1011.0          3.0           0.0         1.0  ...
# 2042     158.0           262.0          1.0           0.0         0.0  ...
# 2043       0.0             0.0          2.0           0.0         1.0  ...
# 2044     329.0           905.0          2.0           0.0         2.0  ...
# 2045     200.0             0.0          3.0           0.0         1.0  ...
#
#       Kitchen AbvGr^2  Kitchen AbvGr Lot Area  Kitchen AbvGr Lot Frontage  \
# 0                 1.0                 13517.0                         0.0
# 1                 1.0                 11492.0                        43.0
# 2                 1.0                  7922.0                        68.0
# 3                 1.0                  9802.0                        73.0
# 4                 1.0                 14235.0                        82.0
# ...               ...                     ...                         ...
# 2041              1.0                 11449.0                        79.0
# 2042              1.0                 12342.0                         0.0
# 2043              1.0                  7558.0                        57.0
# 2044              1.0                 10400.0                        80.0
# 2045              1.0                  7500.0                        60.0
#
#       Kitchen AbvGr Overall Cond   Lot Area^2  Lot Area Lot Frontage  \
# 0                            8.0  182709289.0                    0.0
# 1                            5.0  132066064.0               494156.0
# 2                            7.0   62758084.0               538696.0
# 3                            5.0   96079204.0               715546.0
# 4                            8.0  202635225.0              1167270.0
# ...                          ...          ...                    ...
# 2041                         5.0  131079601.0               904471.0
# 2042                         5.0  152324964.0                    0.0
# 2043                         6.0   57123364.0               430806.0
# 2044                         5.0  108160000.0               832000.0
# 2045                         5.0   56250000.0               450000.0
#
#       Lot Area Overall Cond  Lot Frontage^2  Lot Frontage Overall Cond  \
# 0                  108136.0             0.0                        0.0
# 1                   57460.0          1849.0                      215.0
# 2                   55454.0          4624.0                      476.0
# 3                   49010.0          5329.0                      365.0
# 4                  113880.0          6724.0                      656.0
# ...                     ...             ...                        ...
# 2041                57245.0          6241.0                      395.0
# 2042                61710.0             0.0                        0.0
# 2043                45348.0          3249.0                      342.0
# 2044                52000.0          6400.0                      400.0
# 2045                37500.0          3600.0                      300.0
#
#       Overall Cond^2
# 0               64.0
# 1               25.0
# 2               49.0
# 3               25.0
# 4               64.0
# ...              ...
# 2041            25.0
# 2042            25.0
# 2043            36.0
# 2044            25.0
# 2045            25.0
#
# [2046 rows x 135 columns]

# %%
def evaluate_model(model, X, y): 
    
    y_train_hat = ols.predict(X)

    mse = mean_squared_error(y, y_train_hat)
    rmse = mse ** .5
    r2 = r2_score(y, y_train_hat)

    print(f'R^2: {r2}')
    print(f'MSE: {mse}')
    print(f'RMSE: {rmse}')

# %%
list(train.columns)

# %%
y = train['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

ols = LinearRegression()
ols.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
evaluate_model(ols, X_train, y_train)

# %%
evaluate_model(ols, X_test, y_test)

# %%
cross_val_score(ols, X_poly, y_train).mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-e675551834cc> in <module>
# ----> 1 cross_val_score(ols, X_poly, y_train).mean()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# --> 390                                 error_score=error_score)
#     391     return cv_results['test_score']
#     392
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     219
#     220     """
# --> 221     X, y, groups = indexable(X, y, groups)
#     222
#     223     cv = check_cv(cv, y, classifier=is_classifier(estimator))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     246     """
#     247     result = [_make_indexable(X) for X in iterables]
# --> 248     check_consistent_length(*result)
#     249     return result
#     250
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [2046, 1534]

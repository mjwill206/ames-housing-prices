# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import RidgeCV, LassoCV

import warnings

warnings.filterwarnings('ignore')

train = pd.read_csv('../datasets/train.csv')
test = pd.read_csv('../datasets/test.csv')

# %%
plt.figure(figsize = (8, 12))
sns.heatmap(train.corr()[['SalePrice']].sort_values('SalePrice'),
            annot = True,
            cmap = 'coolwarm',
            vmin = -1,
            vmax = 1)
;
# Out:
# ''

# %%
#train['has fence'] DROP
train['Fence'].fillna('0', inplace = True)
train['has fence'] = train['Fence'].apply(lambda x: 0 if x == '0' else 1)

# %%
train['has fence'].value_counts()
# Out:
# 0    1651
# 1     400
# Name: has fence, dtype: int64

# %%
#age at sale KEEP
train['age at sale'] = train['Yr Sold'] - train['Year Built']

# %%
#age of remod KEEP
train['age remod'] = train['Yr Sold'] - train['Year Remod/Add']

# %%
#overall qual/con DROP
train['Overall QC'] = (train['Overall Qual'] + train['Overall Cond']) / 2

# %%
#total baths KEEP
train['total baths'] = train['Full Bath'] + train['Half Bath']

# %%
train['Garage Area'].fillna(0, inplace = True)
train['Garage Cars'].fillna(0, inplace = True)

# %%
train['Garage Area_Cars'] = train['Garage Area'] * train['Garage Cars']

# %%
def evaluate_model(model, X, y): 
    
    y_train_hat = ols.predict(X)

    mse = mean_squared_error(y, y_train_hat)
    rmse = mse ** .5
    r2 = r2_score(y, y_train_hat)

    print(f'R^2: {r2}')
    print(f'MSE: {mse}')
    print(f'RMSE: {rmse}')

# %%
# REMOVE
train['area by abvgrd'] =  train['Gr Liv Area'] * train['TotRms AbvGrd']

# %%
X = train[['Garage Area_Cars', 'Gr Liv Area', 'age at sale', 'age remod',
          'Overall Qual', 'total baths']]
y = train['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

ols = LinearRegression()
ols.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
evaluate_model(ols, X_train, y_train)
# Out:
# R^2: 0.774772417289129
# MSE: 1424456402.4752185
# RMSE: 37741.97136445338

# %%
evaluate_model(ols, X_test, y_test)
# Out:
# R^2: 0.8237050524519337
# MSE: 1082455337.7739933
# RMSE: 32900.68901670592

# %%
cross_val_score(ols, X_train, y_train).mean()
# Out:
# 0.7624132310395833
